# %% [markdown]
# # Exercício Prático - Análise de Dados com Pandas e Matplotlib
#
# ## Dataset
#
# ecommerce_5000_pedidos.csv
#
# ## Objetivo
#
# Utilizar Pandas para explorar os dados e Matplotlib para criar visualizações que auxiliem na tomada de decisão.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.read_csv('ecommerce_5000_pedidos.csv')

# %% [markdown]
# ## Parte 1 - Conhecendo os Dados
#
# 1. Exiba as 5 primeiras linhas.
# 2. Exiba as 5 últimas linhas.
# 3. Verifique a quantidade de linhas e colunas.
# 4. Identifique os tipos de dados.

# %%
df.head()
# Out:
#    id_pedido data_pedido    categoria         produto  preco_unitario  \
# 0          1  2025-01-20  Informática         Teclado          743.13
# 1          2  2025-03-25  Smartphones          iPhone         2730.87
# 2          3  2025-01-23         Casa  Liquidificador          102.43
# 3          4  2025-06-06        Games        Controle         4608.59
# 4          5  2025-11-27   Escritório  Notebook Stand         6484.24
#
#    quantidade  desconto  valor_total     cidade    forma_pagamento  \
# 0           1      0.12       653.95  Fortaleza             Boleto
# 1           2      0.10      4915.57   Salvador   Cartão de Débito
# 2           1      0.22        79.90  São Paulo  Cartão de Crédito
# 3           1      0.08      4239.90     Recife   Cartão de Débito
# 4           4      0.09     23602.63  Fortaleza   Cartão de Débito
#
#    status_pedido  avaliacao_cliente
# 0       Entregue                  1
# 1  Em Transporte                  5
# ...

# %%
df.tail()
# Out:
#       id_pedido data_pedido    categoria  produto  preco_unitario  quantidade  \
# 4995       4996  2025-07-19        Games  Headset         7998.54           3
# 4996       4997  2025-07-26   Escritório  Cadeira         7650.52           1
# 4997       4998  2025-11-04  Informática      SSD         3338.55           3
# 4998       4999  2025-06-24  Informática    Mouse         5357.97           2
# 4999       5000  2025-11-18   Escritório  Cadeira         3465.18           1
#
#       desconto  valor_total          cidade    forma_pagamento  status_pedido  \
# 4995      0.05     22795.84        Salvador   Cartão de Débito       Entregue
# 4996      0.09      6961.97    Porto Alegre                PIX       Entregue
# 4997      0.18      8212.83       São Paulo             Boleto  Em Transporte
# 4998      0.05     10180.14        Curitiba             Boleto       Entregue
# 4999      0.06      3257.27  Rio de Janeiro  Cartão de Crédito  Em Transporte
#
#       avaliacao_cliente
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_pedido          5000 non-null   int64
#  1   data_pedido        5000 non-null   object
#  2   categoria          5000 non-null   object
#  3   produto            5000 non-null   object
#  4   preco_unitario     5000 non-null   float64
#  5   quantidade         5000 non-null   int64
#  6   desconto           5000 non-null   float64
#  7   valor_total        5000 non-null   float64
#  8   cidade             5000 non-null   object
#  9   forma_pagamento    5000 non-null   object
#  10  status_pedido      5000 non-null   object
#  11  avaliacao_cliente  5000 non-null   int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 468.9+ KB
#          id_pedido  preco_unitario   quantidade     desconto   valor_total  \
# ...

# %% [markdown]
# ## Parte 2 - Estatísticas Básicas
#
# Calcule:
#
# - Média dos pedidos
# - Maior pedido
# - Menor pedido
# - Quantidade de produtos
# - Quantidade de categorias

# %% [markdown]
# ## Parte 3 - Gráfico de Barras
#
# Crie um gráfico de barras mostrando:
#
# Quantidade de pedidos por categoria.
#
# Personalize o gráfico com:
#
# - Título
# - Nome dos eixos
# - Grade

# %%
# Seu código aqui

# %% [markdown]
# ## Parte 4 - Gráfico de Barras
#
# Crie um gráfico de barras mostrando:
#
# Quantidade de pedidos por cidade.
#
# Pergunta:
#
# Qual cidade possui mais pedidos?

# %%
# Seu código aqui

# %% [markdown]
# ## Parte 5 - Gráfico de Pizza
#
# Crie um gráfico de pizza para:
#
# forma_pagamento
#
# Pergunta:
#
# Qual forma de pagamento é mais utilizada?

# %%
# Seu código aqui

# %% [markdown]
# ## Parte 6 - Gráfico de Pizza
#
# Crie um gráfico de pizza para:
#
# status_pedido
#
# Pergunta:
#
# Qual percentual dos pedidos foi entregue?

# %%
# Seu código aqui

# %% [markdown]
# ## Parte 7 - Histograma
#
# Crie um histograma para:
#
# valor_total
#
# Analise:
#
# - Concentração dos pedidos
# - Distribuição dos valores

# %%
# Seu código aqui

# %% [markdown]
# ## Parte 8 - Histograma
#
# Crie um histograma para:
#
# avaliacao_cliente
#
# Pergunta:
#
# Os clientes costumam avaliar bem os produtos?

# %%
# Seu código aqui

# %% [markdown]
# ## Parte 9 - Boxplot
#
# Crie um boxplot para:
#
# valor_total
#
# Analise:
#
# - Outliers
# - Dispersão

# %%
# Seu código aqui

# %% [markdown]
# ## Parte 10 - Boxplot por Categoria
#
# Crie um boxplot comparando:
#
# valor_total por categoria
#
# Pergunta:
#
# Qual categoria possui os pedidos mais caros?

# %%
# Seu código aqui

# %% [markdown]
# ## Parte 11 - Gráfico de Linha
#
# Converta a coluna data_pedido para datetime.
#
# Crie um gráfico mostrando:
#
# Quantidade de pedidos por mês.

# %%
# Seu código aqui

# %% [markdown]
# ## Parte 12 - Faturamento Mensal
#
# Crie um gráfico de linha mostrando:
#
# Faturamento mensal.
#
# Pergunta:
#
# Qual foi o melhor mês de vendas?

# %%
# Seu código aqui

# %% [markdown]
# ## Parte 13 - Scatter Plot
#
# Crie um gráfico de dispersão entre:
#
# desconto x valor_total
#
# Pergunta:
#
# Existe relação entre desconto e valor da compra?

# %%
# Seu código aqui
